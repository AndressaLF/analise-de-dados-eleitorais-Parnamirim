# %% [markdown]
# # Análise de Dados Eleitorais de Parnamirim no 1o turno

# %% [markdown]
# ### Conhecendo as bibliotecas do projeto
#
# Para esse projeto será necessária a instalação das bibliotecas:
# - pandas ([leia a documentação](https://pandas.pydata.org/docs/))
# - matplotlib ([leia a documentação](https://matplotlib.org/stable/index.html))
# - numpy ([leia a documentação](https://numpy.org/doc/stable/))
#
# **ATENÇÃO**: Para entender melhor sobre os dados expressos na base de dados utilizada para a primeira parte, realize a leitura do arquivo .pdf intitulado, [leia-me](leiame.pdf). E para os dados utilizados na segunda parte, realize a leitura do arquivo .pdf intitulado, [leiame_boletim](leiame_boletim.pdf).
#
# Para realizar a instalação das mesmas utilize o comando abaixo:
#
# ```pip install pandas matplotlib jupyter numpy```

# %% [markdown]
# ### Instalando as bibliotecas que serão usadas

# %%
# !pip install pandas matplotlib jupyter numpy
# Out:
# Requirement already satisfied: pandas in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (1.3.5)
# Requirement already satisfied: matplotlib in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (3.6.2)
# Requirement already satisfied: jupyter in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (1.0.0)
# Requirement already satisfied: numpy in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (1.22.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (9.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: jupyter-console in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from jupyter) (6.4.4)
# Requirement already satisfied: nbconvert in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from jupyter) (6.4.1)
# Requirement already satisfied: ipykernel in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from jupyter) (6.9.0)
# Requirement already satisfied: notebook in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from jupyter) (6.4.8)
# Requirement already satisfied: qtconsole in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from jupyter) (5.4.0)
# Requirement already satisfied: ipywidgets in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from jupyter) (7.6.5)
# Requirement already satisfied: six>=1.5 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter) (8.0.1)
# Requirement already satisfied: nest-asyncio in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter) (1.5.4)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter) (7.1.2)
# Requirement already satisfied: traitlets<6.0,>=5.1.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter) (0.1.3)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from ipykernel->jupyter) (1.5.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->jupyter) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->jupyter) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->jupyter) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->jupyter) (1.0.2)
# Requirement already satisfied: pygments in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from jupyter-console->jupyter) (2.11.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from jupyter-console->jupyter) (3.0.27)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter) (0.4)
# WARNING: Ignoring invalid distribution -ypy (c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ypy (c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ypy (c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ypy (c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ypy (c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ypy (c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: testpath in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter) (0.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter) (0.8.4)
# Requirement already satisfied: defusedxml in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter) (0.5.10)
# Requirement already satisfied: bleach in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter) (4.1.0)
# Requirement already satisfied: jinja2>=2.4 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter) (3.0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: jupyter-core in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter) (4.9.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from nbconvert->jupyter) (0.1.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from notebook->jupyter) (0.13.1)
# Requirement already satisfied: prometheus-client in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from notebook->jupyter) (0.13.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from notebook->jupyter) (22.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from notebook->jupyter) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from notebook->jupyter) (21.3.0)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from qtconsole->jupyter) (2.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.18.1)
# Requirement already satisfied: stack-data in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.1.4)
# Requirement already satisfied: decorator in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: colorama in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (65.3.0)
# Requirement already satisfied: black in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (22.1.0)
# Requirement already satisfied: backcall in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.7.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from jinja2>=2.4->nbconvert->jupyter) (2.0.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from jupyter-core->nbconvert->jupyter) (303)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter) (4.4.0)
# Requirement already satisfied: wcwidth in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter) (0.2.5)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from terminado>=0.8.3->notebook->jupyter) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi->notebook->jupyter) (21.2.0)
# Requirement already satisfied: webencodings in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from bleach->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter) (21.4.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter) (1.15.0)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from black->ipython>=7.23.1->ipykernel->jupyter) (2.0.1)
# Requirement already satisfied: platformdirs>=2 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from black->ipython>=7.23.1->ipykernel->jupyter) (2.4.1)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from black->ipython>=7.23.1->ipykernel->jupyter) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from black->ipython>=7.23.1->ipykernel->jupyter) (0.4.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from black->ipython>=7.23.1->ipykernel->jupyter) (8.0.3)
# Requirement already satisfied: executing in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.8.2)
# Requirement already satisfied: asttokens in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: pycparser in c:\users\andressa lima\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter) (2.21)

# %% [markdown]
# ## Parte 2: Análise dos boletins de urna do 1° turno

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Importando e visualizando todos os campos disponíveis para análise

estado_RN = pd.read_csv("boletim_urna_RN.csv", encoding='Latin 1',sep=";" )
estado_RN.sample(10)
# Out:
#         DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 527180  05/10/2022   15:19:40         2022                0
# 314224  05/10/2022   15:19:40         2022                0
# 546171  05/10/2022   15:19:40         2022                0
# 725639  05/10/2022   15:19:40         2022                0
# 370469  05/10/2022   15:19:40         2022                0
# 169241  05/10/2022   15:19:40         2022                0
# 526003  05/10/2022   15:19:40         2022                0
# 454011  05/10/2022   15:19:40         2022                0
# 720488  05/10/2022   15:19:40         2022                0
# 201135  05/10/2022   15:19:40         2022                0
#
#           NM_TIPO_ELEICAO  CD_PLEITO   DT_PLEITO  NR_TURNO  CD_ELEICAO  \
# 527180  Eleição Ordinária        406  02/10/2022         1         546
                 usecols = '''NR_ZONA NR_SECAO NM_MUNICIPIO QT_COMPARECIMENTO QT_APTOS QT_COMPARECIMENTO 
                 QT_ABSTENCOES NR_VOTAVEL NM_VOTAVEL QT_VOTOS DS_CARGO_PERGUNTA'''.split(),
                 sep=";", on_bad_lines = 'skip', encoding='Latin 1')


municipio = estado.query('NM_MUNICIPIO == "PARNAMIRIM" and DS_CARGO_PERGUNTA == "Presidente"')
municipio = municipio.drop(columns = 'NM_MUNICIPIO DS_CARGO_PERGUNTA'.split())


municipio.sample(15)  # visualizando 15 amostras
# Out:
#         NR_ZONA  NR_SECAO  QT_APTOS  QT_COMPARECIMENTO  QT_ABSTENCOES  \
# 688806       50       356       338                284             54
# 681538       50       286       397                322             75
# 687786       50       349       347                281             66
# 681534       50       286       397                322             75
# 675419       50       206       323                267             56
# 674055       50       195       394                323             71
# 668689       50       120       268                231             37
# 707690       50       487       315                258             57
# 693892       50       388       396                324             72
# 673289       50       182       364                298             66
# 672408       50       167       398                330             68
# 678295       50       246       398                329             69
# 664564       50        70       334                290             44
# 709417       50       498       399                343             56
# 674205       50       196       396                342             54
#
#         NR_VOTAVEL      NM_VOTAVEL  QT_VOTOS
# 688806          15    SIMONE TEBET         9
# 681538          80    LÉO PÉRICLES         1
# 687786          22  JAIR BOLSONARO       127
# 681534          15    SIMONE TEBET        16
# 675419          13            LULA       110
# 674055          95          Branco         3
# 668689          22  JAIR BOLSONARO       120
# 707690          15    SIMONE TEBET        10
# 693892          12      CIRO GOMES        18
# 673289          15    SIMONE TEBET         3
# 672408          12      CIRO GOMES        13
# 678295          95          Branco         5
# 664564          15    SIMONE TEBET         5
# 709417          96            Nulo         7
# 674205          30  FELIPE D'AVILA         1

# %% [markdown]
# ## Agrupando os votos por candidato
#
# Para conseguirmos ter idéia da quantidade de votos recebidos por cada candidato temos que agrupar e somar as colunas que contem os nomes dos mesmos e a quantidade de votos.

# %%
municipio.groupby('NM_VOTAVEL')['QT_VOTOS'].sum().sort_values(ascending = False)
# Out:
# NM_VOTAVEL
# JAIR BOLSONARO         53530
# LULA                   48084
# CIRO GOMES              4583
# SIMONE TEBET            2849
# Nulo                    2840
# Branco                  1481
# SORAYA THRONICKE         350
# FELIPE D'AVILA           339
# SOFIA MANZANO             53
# LÉO PÉRICLES              50
# PADRE KELMON              50
# VERA                      29
# CONSTITUINTE EYMAEL       19
# Name: QT_VOTOS, dtype: int64

# %% [markdown]
# ## Porcentagem de votos dos candidatos por seção

# %%
votacao = {}
for secao in municipio.NR_SECAO.unique():
    result = municipio.query('NR_SECAO == @secao').groupby('NM_VOTAVEL')['QT_VOTOS'].sum()
    total = sum(result)
    votacao[secao] = {'Jair Bolsonaro': round(result["JAIR BOLSONARO"] / total * 100, 1),
                     'Lula': round(result["LULA"] / total * 100, 1), 
                     'Simone Tebet': round(result['SIMONE TEBET'] / total * 100, 1),
                     'Nulos':round(result['Nulo'] / total * 100, 1), 
                     'Brancos':round(result['Branco'] / total * 100, 1)
                    }
votacao = pd.DataFrame(votacao).transpose()
votacao

# %% [markdown]
# ## Visualizando a porcentagem de votos por seção(ascendente) - Jair Bolsonaro

# %%
votacao['Jair Bolsonaro'].sort_values(ascending = False)

# %% [markdown]
# ## Visualizando a porcentagem de votos por seção(ascendente) - Lula

# %%
votacao['Lula'].sort_values(ascending = False)

# %%
print (f"Porcentagem de comparecimento {municipio['QT_COMPARECIMENTO'].sum()/municipio['QT_APTOS'].sum()*100:.2f}%")
